# %% [markdown]
# # RoBERTa Cross-Dataset Evaluation
#
# This notebook evaluates the previously fine-tuned RoBERTa AI-text detector on the external HC3 dataset.
#
# The model is not retrained on HC3. This experiment measures how well the model generalizes to human and AI-generated text from a different data source.

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
