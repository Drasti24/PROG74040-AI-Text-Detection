# %%
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification
)

MODEL_ID = "drasti02/ai-text-detector-roberta"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_ID
)

print("Model loaded successfully from Hugging Face Hub.")
# Out:
# config.json:   0%|          | 0.00/740 [00:00<?, ?B/s]
# C:\Users\Drasti\anaconda3\envs\aimlcourse\Lib\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Drasti\.cache\huggingface\hub\models--drasti02--ai-text-detector-roberta. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer_config.json:   0%|          | 0.00/388 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\httpx\_decoders.py:141, in BrotliDecoder.decode(self, data)
#     140 try:
# --> 141     return self._decompress(data)
#     142 except brotli.error as exc:
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\brotlicffi\_api.py:413, in Decompressor.decompress(self, data, output_buffer_limit)
#     412 if self._unconsumed_data and data:
# --> 413     raise error(
#     414         "brotli: decoder process called with data when "
#     415         "'can_accept_more_data()' is False"
#     416     )
#     418 # We should avoid operations on the `self._unconsumed_data` if no data
#     419 # is to be processed.
#
# error: brotli: decoder process called with data when 'can_accept_more_data()' is False
#
# The above exception was the direct cause of the following exception:
#
# DecodingError                             Traceback (most recent call last)
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\transformers\tokenization_utils_base.py:1705, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    1704 try:
# -> 1705     resolved_vocab_files[file_id] = cached_file(
#    1706         pretrained_model_name_or_path,
#    1707         file_path,
#    1708         cache_dir=cache_dir,
#    1709         force_download=force_download,
#    1710         proxies=proxies,
#    1711         local_files_only=local_files_only,
#    1712         token=token,
#    1713         user_agent=user_agent,
#    1714         revision=revision,
#    1715         subfolder=subfolder,
#    1716         _raise_exceptions_for_missing_entries=False,
#    1717         _commit_hash=commit_hash,
#    1718     )
#    1719 except OSError:
#    1720     # Re-raise any error raised by cached_file in order to get a helpful error message
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\transformers\utils\hub.py:294, in cached_file(path_or_repo_id, filename, **kwargs)
#     244 """
#     245 Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     246
#    (...)    292 ```
#     293 """
# --> 294 file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     295 file = file[0] if file is not None else file
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\transformers\utils\hub.py:535, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     534     elif not isinstance(e, EntryNotFoundError):
# --> 535         raise e
#     537 resolved_files = [
#     538     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     539 ]
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\transformers\utils\hub.py:438, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     436 if len(full_filenames) == 1:
#     437     # This is slightly better for only 1 file
# --> 438     hf_hub_download(
#     439         path_or_repo_id,
#     440         filenames[0],
#     441         subfolder=None if len(subfolder) == 0 else subfolder,
#     442         repo_type=repo_type,
#     443         revision=revision,
#     444         cache_dir=cache_dir,
#     445         user_agent=user_agent,
#     446         force_download=force_download,
#     447         proxies=proxies,
#     448         token=token,
#     449         local_files_only=local_files_only,
#     450         tqdm_class=tqdm_class,
#     451     )
#     452 else:
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\huggingface_hub\file_download.py:1019, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#    1018 else:
# -> 1019     return _hf_hub_download_to_cache_dir(
#    1020         # Destination
#    1021         cache_dir=cache_dir,
#    1022         # File info
#    1023         repo_id=repo_id,
#    1024         filename=filename,
#    1025         repo_type=repo_type,
#    1026         revision=revision,
#    1027         # HTTP info
#    1028         endpoint=endpoint,
#    1029         etag_timeout=etag_timeout,
#    1030         headers=hf_headers,
#    1031         token=token,
#    1032         # Additional options
#    1033         local_files_only=local_files_only,
#    1034         force_download=force_download,
#    1035         tqdm_class=tqdm_class,
#    1036         dry_run=dry_run,
#    1037     )
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\huggingface_hub\file_download.py:1242, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1241 with WeakFileLock(lock_path):
# -> 1242     _download_to_tmp_and_move(
#    1243         incomplete_path=Path(blob_path + ".incomplete"),
#    1244         destination_path=Path(blob_path),
#    1245         url_to_download=url_to_download,
#    1246         headers=headers,
#    1247         expected_size=expected_size,
#    1248         filename=filename,
#    1249         force_download=force_download,
#    1250         etag=etag,
#    1251         xet_file_data=xet_file_data,
#    1252         tqdm_class=tqdm_class,
#    1253     )
#    1254     if not os.path.exists(pointer_path):
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\huggingface_hub\file_download.py:1976, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1970             logger.warning(
#    1971                 "Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. "
#    1972                 "Falling back to regular HTTP download. "
#    1973                 "For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`"
#    1974             )
# -> 1976         http_get(
#    1977             url_to_download,
#    1978             f,
#    1979             headers=headers,
#    1980             expected_size=expected_size,
#    1981             tqdm_class=tqdm_class,
#    1982         )
#    1984 logger.debug(f"Download complete. Moving file to {destination_path}")
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\huggingface_hub\file_download.py:439, in http_get(url, temp_file, resume_size, headers, expected_size, displayed_filename, tqdm_class, _nb_retries, _tqdm_bar)
#     438 try:
# --> 439     for chunk in response.iter_bytes(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     440         if chunk:  # filter out keep-alive new chunks
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\httpx\_models.py:898, in Response.iter_bytes(self, chunk_size)
#     897 for raw_bytes in self.iter_raw():
# --> 898     decoded = decoder.decode(raw_bytes)
#     899     for chunk in chunker.decode(decoded):
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\httpx\_decoders.py:143, in BrotliDecoder.decode(self, data)
#     142 except brotli.error as exc:
# --> 143     raise DecodingError(str(exc)) from exc
#
# DecodingError: brotli: decoder process called with data when 'can_accept_more_data()' is False
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 8
#       1 from transformers import (
#       2     AutoTokenizer,
#       3     AutoModelForSequenceClassification
#       4 )
#       6 MODEL_ID = "drasti02/ai-text-detector-roberta"
# ----> 8 tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
#      10 model = AutoModelForSequenceClassification.from_pretrained(
#      11     MODEL_ID
#      12 )
#      14 print("Model loaded successfully from Hugging Face Hub.")
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\transformers\models\auto\tokenization_auto.py:925, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     922     if tokenizer_class is None:
#     923         tokenizer_class = TokenizersBackend
# --> 925     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     926 elif getattr(config, "tokenizer_class", None):
#     927     _class = config.tokenizer_class
#
# File ~\anaconda3\envs\aimlcourse\Lib\site-packages\transformers\tokenization_utils_base.py:1724, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    1721             raise
#    1722         except Exception:
#    1723             # For any other exception, we throw a generic error.
# -> 1724             raise OSError(
#    1725                 f"Can't load tokenizer for '{pretrained_model_name_or_path}'. If you were trying to load it from "
#    1726                 "'https://huggingface.co/models', make sure you don't have a local directory with the same name. "
#    1727                 f"Otherwise, make sure '{pretrained_model_name_or_path}' is the correct path to a directory "
#    1728                 f"containing all relevant files for a {cls.__name__} tokenizer."
#    1729             )
#    1730         commit_hash = extract_commit_hash(resolved_vocab_files[file_id], commit_hash)
#    1732 for file_id, file_path in vocab_files.items():
#
# OSError: Can't load tokenizer for 'drasti02/ai-text-detector-roberta'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'drasti02/ai-text-detector-roberta' is the correct path to a directory containing all relevant files for a RobertaTokenizer tokenizer.
